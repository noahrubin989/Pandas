# %% [markdown]
# ### <span style="color:black"><b>Pandas Tutorial 12</b></span>
#
# <ins>Manipulating a Series & DataFrame in Pandas</ins>
#
# <pre>
# replace()
# apply()
# map()
# applymap()
# </pre>
# * Manipulate a pandas series and dataframe object in a sophisticated manner using `replace()`, `apply()`, `map()` and eventually `applymap()`
# * [Lambda functions](https://towardsdatascience.com/lambda-functions-with-practical-examples-in-python-45934f3653a8), a useful python concept that works really nicely here
#
#
# | Method     | Series | DataFrame |
# |------------|--------|-----------|
# | replace()  | ✅     | ✅        |
# | apply()    | ✅     | ✅        |
# | applymap() | -      | ✅        |
# | map()      | ✅     | -         |

# %% [markdown]
# <u>**Using Map**</u>

# %%
# Unique vals
# Out:
# array(['Yes', 'No', nan], dtype=object)

# %%
# Map 'Yes' to 1 and 'No' to zeroes

# %%
# Change to int since that is what we were originally going for

# %% [markdown]
# <u>**Using Replace**</u>

# %%
# Get genders in our dataset
# Out:
# array(['Man', 'Woman'], dtype=object)

# %%
# Using replace

# %%
# Rename the column to 'Woman'

# %% [markdown]
# <u>**Using Apply & Lambda Functions**</u>

# %%
# For this one work with the NEWOnboardGood column
df.NEWOnboardGood.unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
# Use our lambda function

# %% [markdown]
# #### 🧠 **Exercise**
# * Do the same thing with the 'NEWOtherComms' series but this time use a custom function

# %%
# NEWOtherComms uniques
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
# Function

# %%
# Apply function to our series

# %% [markdown]
# #### 🧠 **Exercise**
# * Who is the most ambitious employee?

# %%
def count_number_of_platforms(mystring):
    try:
        if len(mystring.strip()) == 0:
            return 0
        list_of_strings = mystring.split(';')
        return len(list_of_strings)
    except AttributeError:
        return 0

# %%
df['Number of platforms that they want to work with'] = df['PlatformDesireNextYear'].apply(count_number_of_platforms)

# %%
df_sorted = df.sort_values(by = 'Number of platforms that they want to work with', ascending = False)
df_sorted[['Number of platforms that they want to work with', 'Age']]
# Out:
#       Number of platforms that they want to work with   Age
# 1629                                               16  27.0
# 1758                                               16  46.0
# 1569                                               15  23.0
# 1166                                               15  35.0
# 2156                                               14  27.0
# ...                                               ...   ...
# 1142                                                0  54.0
# 1824                                                0  25.0
# 1828                                                0  25.0
# 2665                                                0  48.0
# 2562                                                0  29.0
#
# [2897 rows x 2 columns]

# %%
# df_sorted.plot(kind = 'scatter', 
#                x = 'Age', 
#                y ='Number of platforms that they want to work with');

# %% [markdown]
# #### 🧠 **Exercise**
# * Take the 'OrgSize' series and convert it completely into numeric form

# %%
def string_to_num(mystring):
    """Takes all numbers out of the string and places them in a list, taking the average afterwards"""
    try:
        if mystring == 'Just me - I am a freelancer, sole proprietor, etc.':
            return 1
        number_list = nums_from_string.get_nums(mystring)
        avg = np.mean(number_list)
        return int(round(avg, 0))
    except (ValueError, RuntimeWarning):
        return -999

# %%
# Apply the function
df['OrgSize'] = df['OrgSize'].apply(string_to_num)

# %%
df.OrgSize
# Out:
# 0          60
# 1       10000
# 2           6
# 3           6
# 4          14
#         ...
# 2892      300
# 2893      300
# 2894     7500
# 2895       14
# 2896      300
# Name: OrgSize, Length: 2897, dtype: int64

# %% [markdown]
# #### 🧠 **Exercise**
# * Adjust the 'JobSat' series to return a satisfaction score (use any method you like)

# %%
df.JobSat.unique()
# Out:
# array(['Very satisfied', 'Slightly satisfied', 'Slightly dissatisfied',
#        'Neither satisfied nor dissatisfied', 'Very dissatisfied'],
#       dtype=object)

# %%
mapping_vals = {'Very satisfied':9, 
                'Slightly satisfied': 6,
                'Very dissatisfied': 2,
                'Neither satisfied nor dissatisfied': 5,
                'Slightly dissatisfied': 4}

df['JobSat'] = df['JobSat'].map(mapping_vals)

# %% [markdown]
# ## <span style="color:black"><u>Manipulating a Dataframe</u></span>
#
# * Now we will go through is how to use the `apply()` method on a dataframe rather than a series
# * The main difference between `apply()` as a series method vs as a dataframe method is that when we can now consider many columns in our functions
# * The idea is very similar to what we did on a series but now we have to set our axis parameter to either 0 or 1, depending on whether we want to do operations row wise or column wise
# * After that we will explore `applymap()` - one of my favourites
#
# ---
#
# #### 🧠 **Exercise**
#
# * Use `apply()` as a dataframe methopd to create a column called Bio that considers <u>multiple columns</u> such as the respondent id, country and age and salary

# %%
def create_bio(data):
    return f"""I am respondent {data['Respondent']} and I am a {data['Age']} 
    year old from {data['Country']} who earns {data['CompTotal']}
    """

# %%
df['Bio'] = df.apply(create_bio, axis = 'columns')

# %%
df.head(2)
# Out:
#    Respondent  Hobbyist   Age CompFreq  CompTotal        Country  \
# 0        69.0         1  25.0   Yearly   550000.0         France
# 1        80.0         1  32.0   Yearly    94500.0  United States
#
#   CurrencySymbol                                          EdLevel  \
# 0            EUR  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 1            USD     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#            Employment  JobSat NEWDevOps     NEWLearn NEWOffTopic  \
# 0  Employed full-time       9       Yes  Once a year          No
# 1  Employed full-time       9       Yes  Once a year    Not sure
#
#    NEWOnboardGood  NEWOtherComms  \
# 0               0              0
# 1               0              0
#
#                                             NEWStuck  OrgSize  \
# 0  Call a coworker or friend;Visit Stack Overflow...       60
# 1  Call a coworker or friend;Visit Stack Overflow...    10000
#
#                             PlatformDesireNextYear  Woman  \
# 0                                 Kubernetes;Linux      0
# 1  Docker;Kubernetes;Linux;Microsoft Azure;Windows      1
#
#                                       UndergradMajor  \
# 0  Computer science, computer engineering, or sof...
# 1  Information systems, information technology, o...
#
#    Number of platforms that they want to work with  \
# 0                                                2
# 1                                                5
#
#                                                  Bio
# 0  I am respondent 69.0 and I am a 25.0 \n    yea...
# 1  I am respondent 80.0 and I am a 32.0 \n    yea...

# %% [markdown]
# #### 🧠 **IDEA**
# Turn the CompTotal series into Aussie dollars. [Here](https://medium.com/analytics-vidhya/convert-currencies-automatically-with-python-python-in-audit-2-6c574dbae44) is a program that basically does exctly this using apply!
#
# Anyway, onto applymap...
#
# ---

# %% [markdown]
# <u>applymap()</u>
#
# * `applymap()` in pandas is very similar to everything that we have just covered and is best used when we wish to adjust every individual entry in our dataframe
# * No axis argument is needed here as we are now just sweeping through each individual element in the dataframe (without the need for a `for` loop may I add)
# * This is nice if we would like to change each and every integer value into a float, or get every string in uppercase over our entire dataset
#
# ---
#
# This is best done through an example:
#
# * Suppose that we were concerned that there was a row 'france' but also 'France ', 'FranCE' and 'fRanCe'
# * Suppose that in the CurrencySymbol series we were also concerned that there was a value 'EUR' but also 'eur   ' even though they are both supposed to represent the same thing
# * Use `applymap()` to solve this problem by getting everything into lower case with stripped whitespace so that there are no case issues and no whitespace issues
# * This is easily in my top 10 favourite lines of pandas code
# * My favourite line of pandas code will be in the video about `pd.concat()` 👀

# %%
# "for each entry, put it into lowercase and strip whitespace if it is a string, otherwise just leave it as it is"
df = df.applymap(lambda x: x.lower().strip() if type(x) == str else x)

# %%
# A silly example - Take each numeric element and square it for no reason whatsoever
# Of course we will not be saving this to a new dataframe
df.applymap(lambda x: x**2 if type(x) in [int, float] else x)
# Out:
#         Respondent Hobbyist     Age CompFreq     CompTotal         Country  \
# 0     4.761000e+03        1   625.0   yearly  3.025000e+11          france
# 1     6.400000e+03        1  1024.0   yearly  8.930250e+09   united states
# 2     1.416100e+04        1  1225.0   yearly  2.102500e+10   united states
# 3     1.638400e+04        1   529.0   yearly  6.400000e+09   united states
# 4     1.716100e+04        1  1369.0   yearly  1.322500e+10   united states
# ...            ...      ...     ...      ...           ...             ...
# 2892  3.951757e+09        1   900.0   yearly  5.290000e+10   united states
# 2893  3.954649e+09        1  1024.0   yearly  1.054729e+10   united states
# 2894  3.956913e+09        1  1089.0   yearly  9.025000e+09   united states
# 2895  4.005371e+09        0   961.0   yearly  4.225000e+09  united kingdom
# 2896  4.216944e+09        0  1089.0   yearly  3.025000e+09          france
#
#      CurrencySymbol                                            EdLevel  \
# 0               eur    master’s degree (m.a., m.s., m.eng., mba, etc.)
# 1               usd       bachelor’s degree (b.a., b.s., b.eng., etc.)
# 2               usd       bachelor’s degree (b.a., b.s., b.eng., etc.)
# 3               usd  some college/university study without earning ...
# 4               usd       bachelor’s degree (b.a., b.s., b.eng., etc.)
# ...             ...                                                ...
# 2892            usd       bachelor’s degree (b.a., b.s., b.eng., etc.)
# 2893            usd    master’s degree (m.a., m.s., m.eng., mba, etc.)
# 2894            usd                associate degree (a.a., a.s., etc.)
# 2895            gbp       bachelor’s degree (b.a., b.s., b.eng., etc.)
# 2896            eur                 professional degree (jd, md, etc.)
#
#               Employment  JobSat NEWDevOps              NEWLearn NEWOffTopic  \
# 0     employed full-time      81       yes           once a year          no
# 1     employed full-time      81       yes           once a year    not sure
# 2     employed full-time      81       yes                   NaN          no
# 3     employed full-time      36        no           once a year    not sure
# 4     employed full-time      36        no      every few months          no
# ...                  ...     ...       ...                   ...         ...
# 2892  employed full-time      36       yes      every few months    not sure
# 2893  employed full-time      36        no  once every few years         yes
# 2894  employed full-time      36       yes      every few months    not sure
# 2895  employed full-time      81       yes      every few months    not sure
# 2896  employed full-time      81       yes           once a year    not sure
#
#       NEWOnboardGood  NEWOtherComms  \
# 0                  0              0
# 1                  0              0
# 2                  1              1
# 3                  0              0
# 4                  1              1
# ...              ...            ...
# 2892               0              0
# 2893               1              0
# 2894               1              1
# 2895               0              0
# 2896               1              0
#
#                                                NEWStuck    OrgSize  \
# 0     call a coworker or friend;visit stack overflow...       3600
# 1     call a coworker or friend;visit stack overflow...  100000000
# 2     meditate;call a coworker or friend;visit stack...         36
# 3     play games;visit stack overflow;go for a walk ...         36
# 4     visit stack overflow;go for a walk or other ph...        196
# ...                                                 ...        ...
# 2892  play games;visit stack overflow;go for a walk ...      90000
# 2893  call a coworker or friend;visit stack overflow...      90000
# 2894  call a coworker or friend;visit stack overflow...   56250000
# 2895  visit stack overflow;watch help / tutorial vid...        196
# 2896  call a coworker or friend;visit stack overflow...      90000
#
#                                  PlatformDesireNextYear  Woman  \
# 0                                      kubernetes;linux      0
# 1       docker;kubernetes;linux;microsoft azure;windows      1
# 2     docker;kubernetes;linux;macos;microsoft azure;...      1
# 3                                        android;docker      1
# 4               arduino;aws;docker;raspberry pi;windows      1
# ...                                                 ...    ...
# 2892                 docker;slack apps and integrations      0
# 2893                     docker;microsoft azure;windows      1
# 2894  aws;docker;heroku;kubernetes;linux;macos;raspb...      1
# 2895                                         kubernetes      0
# 2896                                       docker;linux      0
#
#                                          UndergradMajor  \
# 0     computer science, computer engineering, or sof...
# 1     information systems, information technology, o...
# 2     another engineering discipline (such as civil,...
# 3     computer science, computer engineering, or sof...
# 4                             mathematics or statistics
# ...                                                 ...
# 2892  information systems, information technology, o...
# 2893  information systems, information technology, o...
# 2894  computer science, computer engineering, or sof...
# 2895  computer science, computer engineering, or sof...
# 2896  computer science, computer engineering, or sof...
#
#       Number of platforms that they want to work with  \
# 0                                                   4
# 1                                                  25
# 2                                                  36
# 3                                                   4
# 4                                                  25
# ...                                               ...
# 2892                                                4
# 2893                                                9
# 2894                                               49
# 2895                                                1
# 2896                                                4
#
#                                                     Bio
# 0     i am respondent 69.0 and i am a 25.0 \n    yea...
# 1     i am respondent 80.0 and i am a 32.0 \n    yea...
# 2     i am respondent 119.0 and i am a 35.0 \n    ye...
# 3     i am respondent 128.0 and i am a 23.0 \n    ye...
# 4     i am respondent 131.0 and i am a 37.0 \n    ye...
# ...                                                 ...
# 2892  i am respondent 62863.0 and i am a 30.0 \n    ...
# 2893  i am respondent 62886.0 and i am a 32.0 \n    ...
# 2894  i am respondent 62904.0 and i am a 33.0 \n    ...
# 2895  i am respondent 63288.0 and i am a 31.0 \n    ...
# 2896  i am respondent 64938.0 and i am a 33.0 \n    ...
#
# [2897 rows x 22 columns]
