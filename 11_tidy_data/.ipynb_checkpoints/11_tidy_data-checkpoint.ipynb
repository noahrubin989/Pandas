# %% [markdown]
# ### <span style="color:black"><b>Pandas Tutorial 11</b></span>
#
# <ins>Tidy Data</ins>
#
# Definitions of a tidy dataset can be subjective at times, though most people would agree on the fact that tidy data normally displays the following characteristics
#
# * Each variable has its own column.
# * Each observation is its own row.
# * Each value must have its own cell
#
# Pandas has a dataframe method called `df.melt()` that helps with this
#
# Why bother?
#
# ---
#
# Here is what [Hadley Wickam](http://hadley.nz/) (a major contributer to the R programming language)  has to say:
# * There’s a general advantage to picking one consistent way of storing data. If you have a consistent data structure, it’s easier to learn the tools that work with it because they have an underlying uniformity
# * Tidy datasets are easy to manipulate, model and visualise, and have a specific structure
# * Tidy datasets provide a standardised way to link the structure of a dataset (its physical layout)
# with its semantics (its meaning).
#
# ---
#
# [Easily my favourite resource on tidy data](https://vita.had.co.nz/papers/tidy-data.pdf)

# %%
import pandas as pd

# %%
f_rates = pd.read_csv('fertility_rates.csv')
f_rates.head()
# Out:
#                   Country Name Country Code      1960      1961      1962  \
# 0                        Aruba          ABW  4.820000  4.655000  4.471000
# 1  Africa Eastern and Southern          AFE  6.723308  6.738651  6.752818
# 2                  Afghanistan          AFG  7.450000  7.450000  7.450000
# 3   Africa Western and Central          AFW  6.439002  6.455523  6.471399
# 4                       Angola          AGO  6.708000  6.790000  6.872000
#
#        1963      1964      1965      1966      1967  ...      2011      2012  \
# 0  4.271000  4.059000  3.842000  3.625000  3.417000  ...  1.779000  1.795000
# 1  6.765400  6.775406  6.783357  6.789885  6.796040  ...  4.956842  4.882058
# 2  7.450000  7.450000  7.450000  7.450000  7.450000  ...  5.770000  5.562000
# 3  6.487246  6.502619  6.519050  6.537615  6.560078  ...  5.557872  5.503781
# 4  6.954000  7.036000  7.116000  7.194000  7.267000  ...  6.120000  6.039000
#
#        2013      2014      2015      2016      2017      2018      2019  2020
# 0  1.813000  1.834000  1.854000  1.872000  1.886000  1.896000  1.901000   NaN
# 1  4.804516  4.726220  4.647637  4.569675  4.493744  4.420264  4.349433   NaN
# 2  5.359000  5.163000  4.976000  4.800000  4.633000  4.473000  4.321000   NaN
# 3  5.446144  5.384336  5.319473  5.251674  5.182391  5.113003  5.044144   NaN
# 4  5.953000  5.864000  5.774000  5.686000  5.600000  5.519000  5.442000   NaN
#
# [5 rows x 63 columns]

# %%
f_rates.melt(id_vars=['Country Name', 'Country Code'], var_name='Year', value_name='Fertility Rates')
# Out:
#                       Country Name Country Code  Year  Fertility Rates
# 0                            Aruba          ABW  1960         4.820000
# 1      Africa Eastern and Southern          AFE  1960         6.723308
# 2                      Afghanistan          AFG  1960         7.450000
# 3       Africa Western and Central          AFW  1960         6.439002
# 4                           Angola          AGO  1960         6.708000
# ...                            ...          ...   ...              ...
# 16221                       Kosovo          XKX  2020              NaN
# 16222                  Yemen, Rep.          YEM  2020              NaN
# 16223                 South Africa          ZAF  2020              NaN
# 16224                       Zambia          ZMB  2020              NaN
# 16225                     Zimbabwe          ZWE  2020              NaN
#
# [16226 rows x 4 columns]

# %%
df = pd.read_csv('exchange_rates.csv')
df.head()
# Out:
#                Currency  20 Aug 2021  23 Aug 2021  24 Aug 2021  25 Aug 2021
# 0  United States dollar       0.7133       0.7161       0.7234       0.7245
# 1      Chinese renminbi       4.6375       4.6494       4.6869       4.6925
# 2          Japanese yen      78.2400      78.7400      79.4500      79.4800
# 3         European euro       0.6103       0.6112       0.6161       0.6170
# 4      South Korean won     841.7500     840.3600     843.8100     845.7300

# %%
df_melted = df.melt(id_vars=['Currency'], var_name='Date', value_name='Units of foreign corrency per Australian Dollar')
df_melted
# Out:
#                  Currency         Date  \
# 0    United States dollar  20 Aug 2021
# 1        Chinese renminbi  20 Aug 2021
# 2            Japanese yen  20 Aug 2021
# 3           European euro  20 Aug 2021
# 4        South Korean won  20 Aug 2021
# ..                    ...          ...
# 67        Vietnamese dong  25 Aug 2021
# 68       Hong Kong dollar  25 Aug 2021
# 69  Papua New Guinea kina  25 Aug 2021
# 70            Swiss franc  25 Aug 2021
# 71        Canadian dollar  25 Aug 2021
#
#     Units of foreign corrency per Australian Dollar
# 0                                            0.7133
# 1                                            4.6375
# 2                                           78.2400
# 3                                            0.6103
# 4                                          841.7500
# ..                                              ...
# 67                                       16526.0000
# 68                                           5.6398
# 69                                           2.5421
# 70                                           0.6623
# 71                                           0.9141
#
# [72 rows x 3 columns]

# %%
df_melted['Date'] = pd.to_datetime(df_melted['Date'])
df_melted.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 72 entries, 0 to 71
# Data columns (total 3 columns):
#  #   Column                                           Non-Null Count  Dtype
# ---  ------                                           --------------  -----
#  0   Currency                                         72 non-null     object
#  1   Date                                             72 non-null     datetime64[ns]
#  2   Units of foreign corrency per Australian Dollar  72 non-null     float64
# dtypes: datetime64[ns](1), float64(1), object(1)
# memory usage: 1.8+ KB

# %%
df_melted
# Out:
#                  Currency       Date  \
# 0    United States dollar 2021-08-20
# 1        Chinese renminbi 2021-08-20
# 2            Japanese yen 2021-08-20
# 3           European euro 2021-08-20
# 4        South Korean won 2021-08-20
# ..                    ...        ...
# 67        Vietnamese dong 2021-08-25
# 68       Hong Kong dollar 2021-08-25
# 69  Papua New Guinea kina 2021-08-25
# 70            Swiss franc 2021-08-25
# 71        Canadian dollar 2021-08-25
#
#     Units of foreign corrency per Australian Dollar
# 0                                            0.7133
# 1                                            4.6375
# 2                                           78.2400
# 3                                            0.6103
# 4                                          841.7500
# ..                                              ...
# 67                                       16526.0000
# 68                                           5.6398
# 69                                           2.5421
# 70                                           0.6623
# 71                                           0.9141
#
# [72 rows x 3 columns]

# %%
df['Date'] = pd.to_datetime(df['Date'])
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/anaconda3/envs/Models/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Date'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-26-e0d9d975d684> in <module>
# ----> 1 df['Date'] = pd.to_datetime(df['Date'])
#       2 df
#
# /opt/anaconda3/envs/Models/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3022             if self.columns.nlevels > 1:
#    3023                 return self._getitem_multilevel(key)
# -> 3024             indexer = self.columns.get_loc(key)
#    3025             if is_integer(indexer):
#    3026                 indexer = [indexer]
#
# /opt/anaconda3/envs/Models/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#    3084         if tolerance is not None:
#
# KeyError: 'Date'

# %%
'Units of foreign corrency per Australian Dollar'

# %% [markdown]
# <u>**Example 1**</u>

# %%
df1 = pd.read_csv("gdp_stats.csv")
df1

# %%
df1 = df1.melt(id_vars = ['Country Name'], var_name = 'Year', value_name = 'GDP Growth Percentage').copy()

# %%
df1

# %% [markdown]
# <u>**Example 2:**</u>

# %%
df2 = pd.read_csv("exchange_rates.csv")
df2

# %%
df2 = df2.melt(id_vars = 'Currency', var_name = 'Date', value_name = 'Units of Foreign Currency per Australian Dollar')

# %%
# Now we can do things like convert to a date
df2['Date'] = pd.to_datetime(df2.Date)
df2
