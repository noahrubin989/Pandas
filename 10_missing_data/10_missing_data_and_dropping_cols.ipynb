# %% [markdown]
# ### <span style="color:black"><b>Pandas Tutorial 10</b></span>
#  FIX THIS NOTEBOOK UP
# ---
#
# - Dealing with Missing Data
# - Dropping Rows + Columns
#
# ---
#
# **Useful DataFrame Methods**
#
# <pre>
# df.isna() or df.isnull()
# df.fillna()
# df.dropna()
# df.drop()
# </pre>
#
# Important arguments
# <pre>
# axis
# inplace
# </pre>

# %%
import numpy as np
import pandas as pd
# %config InlineBackend.figure_format = 'svg'

# %% [markdown]
# **1. Initial cleaning while reading in data**

# %%
df = pd.read_csv('2018_health.csv', na_values=['?', '--', '..'])
df.head(10)
# Out:
#    Unnamed: 0          GDP/Capita  MeanSchooling  InfantMortality  Life_exp  \
# 0           0                 NaN            3.9              NaN       NaN
# 1           1             missing           10.1              8.5    78.458
# 2           2   4153.733978059152            NaN             20.4       NaN
# 3           3  11633.498008646506            NaN              8.7    76.520
# 4           4   4220.490276712489           11.3             11.0    74.945
# 5           5   57354.96404558911           12.7              3.1       NaN
# 6           6  4739.8417102839285           10.6             19.3    72.864
# 7           7   23991.05667693996            9.4              6.1    77.163
# 8           8  1698.3503942812197            6.1             26.7    72.320
# 9           9   17745.19346499627           10.6             12.1    79.081
#
#        Country    Year Country Type
# 0  Afghanistan  2018.0   Developing
# 1      Albania  2018.0   Developing
# 2      Algeria  2018.0   Developing
# 3    Argentina  2018.0   Developing
# 4      Armenia  2018.0   Developing
# 5    Australia  2018.0    Developed
# 6   Azerbaijan  2018.0   Developing
# 7      Bahrain  2018.0   Developing
# 8   Bangladesh  2018.0   Developing
# 9     Barbados  2018.0   Developing

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 122 entries, 0 to 121
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       122 non-null    int64
#  1   GDP/Capita       118 non-null    object
#  2   MeanSchooling    15 non-null     float64
#  3   InfantMortality  121 non-null    float64
#  4   Life_exp         119 non-null    float64
#  5   Country          122 non-null    object
#  6   Year             121 non-null    float64
#  7   Country Type     122 non-null    object
# dtypes: float64(4), int64(1), object(3)
# memory usage: 7.8+ KB

# %% [markdown]
# **1. Finding where missing values are for a particular series**
#
# - Example: Find all rows where MeanSchooling was missing

# %%
df.loc[df['MeanSchooling'].isnull(), :]
# Out:
#      Unnamed: 0          GDP/Capita  MeanSchooling  InfantMortality  \
# 2             2   4153.733978059152            NaN             20.4
# 3             3  11633.498008646506            NaN              8.7
# 17           17   813.0968489600382            NaN             55.3
# 18           18  271.75204437664803            NaN             41.2
# 19           19  1512.1267097284697            NaN             23.7
# ..          ...                 ...            ...              ...
# 117         117    43043.2278164551            NaN              3.7
# 118         118   62996.47128526045            NaN              5.6
# 119         119  17277.970110549588            NaN              6.5
# 120         120                 NaN            NaN             16.5
# 121         121                 NaN            NaN             22.4
#
#       Life_exp         Country    Year Country Type
# 2          NaN         Algeria  2018.0   Developing
# 3    76.520000       Argentina  2018.0   Developing
# 17   61.174000    Burkina Faso  2018.0   Developing
# 18   61.247000         Burundi  2018.0   Developing
# 19   69.570000        Cambodia  2018.0   Developing
# ..         ...             ...     ...          ...
# 117  81.256098  United Kingdom     NaN    Developed
# 118  78.539024   United States  2018.0    Developed
# 119  77.770000         Uruguay  2018.0   Developing
# 120  71.573000      Uzbekistan  2018.0   Developing
# 121  70.323000         Vanuatu  2018.0   Developing
#
# [107 rows x 8 columns]

# %% [markdown]
# Example: Find all rows where Life_exp was missing

# %%
df.loc[df.Life_exp.isnull(), :]
# Out:
#    Unnamed: 0         GDP/Capita  MeanSchooling  InfantMortality  Life_exp  \
# 0           0                NaN            3.9              NaN       NaN
# 2           2  4153.733978059152            NaN             20.4       NaN
# 5           5  57354.96404558911           12.7              3.1       NaN
#
#        Country    Year Country Type
# 0  Afghanistan  2018.0   Developing
# 2      Algeria  2018.0   Developing
# 5    Australia  2018.0    Developed

# %% [markdown]
# **3. Counting how many missing values there are in our dataset**

# %%
df.isna().sum()
# Out:
# Unnamed: 0           0
# GDP/Capita           4
# MeanSchooling      107
# InfantMortality      1
# Life_exp             3
# Country              0
# Year                 1
# Country Type         0
# dtype: int64

# %% [markdown]
# **4. Seeing where ALL these values are**

# %%
df.loc[df.isnull().any(axis='columns'), :]
# Out:
#      Unnamed: 0          GDP/Capita  MeanSchooling  InfantMortality  \
# 0             0                 NaN            3.9              NaN
# 2             2   4153.733978059152            NaN             20.4
# 3             3  11633.498008646506            NaN              8.7
# 5             5   57354.96404558911           12.7              3.1
# 17           17   813.0968489600382            NaN             55.3
# ..          ...                 ...            ...              ...
# 117         117    43043.2278164551            NaN              3.7
# 118         118   62996.47128526045            NaN              5.6
# 119         119  17277.970110549588            NaN              6.5
# 120         120                 NaN            NaN             16.5
# 121         121                 NaN            NaN             22.4
#
#       Life_exp         Country    Year Country Type
# 0          NaN     Afghanistan  2018.0   Developing
# 2          NaN         Algeria  2018.0   Developing
# 3    76.520000       Argentina  2018.0   Developing
# 5          NaN       Australia  2018.0    Developed
# 17   61.174000    Burkina Faso  2018.0   Developing
# ..         ...             ...     ...          ...
# 117  81.256098  United Kingdom     NaN    Developed
# 118  78.539024   United States  2018.0    Developed
# 119  77.770000         Uruguay  2018.0   Developing
# 120  71.573000      Uzbekistan  2018.0   Developing
# 121  70.323000         Vanuatu  2018.0   Developing
#
# [109 rows x 8 columns]

# %% [markdown]
# **5. Filling in missing values (for a series) with either a constant or the output from an aggregation function**

# %%
# Fill with 20_000 just to see how it works
df['GDP/Capita'].fillna(value = 20_000, inplace=True)

# %%
# Don't use inplace = True, just so that nothing is committed to
school_mean = df['MeanSchooling'].mean()

df['MeanSchooling'].fillna(value=school_mean)
# Out:
# 0       3.900000
# 1      10.100000
# 2       8.906667
# 3       8.906667
# 4      11.300000
#          ...
# 117     8.906667
# 118     8.906667
# 119     8.906667
# 120     8.906667
# 121     8.906667
# Name: MeanSchooling, Length: 122, dtype: float64

# %% [markdown]
# **6. Fill in a miising values across an entire df**

# %%
df
# Out:
#      Unnamed: 0          GDP/Capita  MeanSchooling  InfantMortality  \
# 0             0               20000            3.9              NaN
# 1             1             missing           10.1              8.5
# 2             2   4153.733978059152            NaN             20.4
# 3             3  11633.498008646506            NaN              8.7
# 4             4   4220.490276712489           11.3             11.0
# ..          ...                 ...            ...              ...
# 117         117    43043.2278164551            NaN              3.7
# 118         118   62996.47128526045            NaN              5.6
# 119         119  17277.970110549588            NaN              6.5
# 120         120               20000            NaN             16.5
# 121         121               20000            NaN             22.4
#
#       Life_exp         Country    Year Country Type
# 0          NaN     Afghanistan  2018.0   Developing
# 1    78.458000         Albania  2018.0   Developing
# 2          NaN         Algeria  2018.0   Developing
# 3    76.520000       Argentina  2018.0   Developing
# 4    74.945000         Armenia  2018.0   Developing
# ..         ...             ...     ...          ...
# 117  81.256098  United Kingdom     NaN    Developed
# 118  78.539024   United States  2018.0    Developed
# 119  77.770000         Uruguay  2018.0   Developing
# 120  71.573000      Uzbekistan  2018.0   Developing
# 121  70.323000         Vanuatu  2018.0   Developing
#
# [122 rows x 8 columns]

# %%
df.fillna(value = df.mean())
# Out:
#      Unnamed: 0          GDP/Capita  MeanSchooling  InfantMortality  \
# 0             0               20000       3.900000        20.004959
# 1             1             missing      10.100000         8.500000
# 2             2   4153.733978059152       8.906667        20.400000
# 3             3  11633.498008646506       8.906667         8.700000
# 4             4   4220.490276712489      11.300000        11.000000
# ..          ...                 ...            ...              ...
# 117         117    43043.2278164551       8.906667         3.700000
# 118         118   62996.47128526045       8.906667         5.600000
# 119         119  17277.970110549588       8.906667         6.500000
# 120         120               20000       8.906667        16.500000
# 121         121               20000       8.906667        22.400000
#
#       Life_exp         Country    Year Country Type
# 0    72.900215     Afghanistan  2018.0   Developing
# 1    78.458000         Albania  2018.0   Developing
# 2    72.900215         Algeria  2018.0   Developing
# 3    76.520000       Argentina  2018.0   Developing
# 4    74.945000         Armenia  2018.0   Developing
# ..         ...             ...     ...          ...
# 117  81.256098  United Kingdom  2018.0    Developed
# 118  78.539024   United States  2018.0    Developed
# 119  77.770000         Uruguay  2018.0   Developing
# 120  71.573000      Uzbekistan  2018.0   Developing
# 121  70.323000         Vanuatu  2018.0   Developing
#
# [122 rows x 8 columns]

# %%
values_to_fill = {'GDP/Capita':df['GDP/Capita'].mean(), 
                  'MeanSchooling':10, 
                  'InfantMortality':df['InfantMortality'].median()}

# Use fillna() as a dataframe method
df.fillna(value = values_to_fill)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-c4ef372ccc16> in <module>
# ----> 1 values_to_fill = {'GDP/Capita':df['GDP/Capita'].mean(),
#       2                   'MeanSchooling':10,
#       3                   'InfantMortality':df['InfantMortality'].median()}
#       4
#       5 # Use fillna() as a dataframe method
#
# /opt/anaconda3/envs/Models/lib/python3.8/site-packages/pandas/core/generic.py in mean(self, axis, skipna, level, numeric_only, **kwargs)
#   11116         )
#   11117         def mean(self, axis=None, skipna=None, level=None, numeric_only=None, **kwargs):
# > 11118             return NDFrame.mean(self, axis, skipna, level, numeric_only, **kwargs)
#   11119
#   11120         # pandas\core\generic.py:10924: error: Cannot assign to a method
#
# /opt/anaconda3/envs/Models/lib/python3.8/site-packages/pandas/core/generic.py in mean(self, axis, skipna, level, numeric_only, **kwargs)
#   10724
#   10725     def mean(self, axis=None, skipna=None, level=None, numeric_only=None, **kwargs):
# > 10726         return self._stat_function(
#   10727             "mean", nanops.nanmean, axis, skipna, level, numeric_only, **kwargs
#   10728         )
#
# /opt/anaconda3/envs/Models/lib/python3.8/site-packages/pandas/core/generic.py in _stat_function(self, name, func, axis, skipna, level, numeric_only, **kwargs)
#   10709         if level is not None:
#   10710             return self._agg_by_level(name, axis=axis, level=level, skipna=skipna)
# > 10711         return self._reduce(
#   10712             func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   10713         )
#
# /opt/anaconda3/envs/Models/lib/python3.8/site-packages/pandas/core/series.py in _reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    4180                 )
#    4181             with np.errstate(all="ignore"):
# -> 4182                 return op(delegate, skipna=skipna, **kwds)
#    4183
#    4184     def _reindex_indexer(self, new_index, indexer, copy):
#
# /opt/anaconda3/envs/Models/lib/python3.8/site-packages/pandas/core/nanops.py in _f(*args, **kwargs)
#      71             try:
#      72                 with np.errstate(invalid="ignore"):
# ---> 73                     return f(*args, **kwargs)
#      74             except ValueError as e:
#      75                 # we want to transform an object array
#
# /opt/anaconda3/envs/Models/lib/python3.8/site-packages/pandas/core/nanops.py in f(values, axis, skipna, **kwds)
#     133                     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     134             else:
# --> 135                 result = alt(values, axis=axis, skipna=skipna, **kwds)
#     136
#     137             return result
#
# /opt/anaconda3/envs/Models/lib/python3.8/site-packages/pandas/core/nanops.py in new_func(values, axis, skipna, mask, **kwargs)
#     392             mask = isna(values)
#     393
# --> 394         result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     395
#     396         if datetimelike:
#
# /opt/anaconda3/envs/Models/lib/python3.8/site-packages/pandas/core/nanops.py in nanmean(values, axis, skipna, mask)
#     631
#     632     count = _get_counts(values.shape, mask, axis, dtype=dtype_count)
# --> 633     the_sum = _ensure_numeric(values.sum(axis, dtype=dtype_sum))
#     634
#     635     if axis is not None and getattr(the_sum, "ndim", False):
#
# /opt/anaconda3/envs/Models/lib/python3.8/site-packages/numpy/core/_methods.py in _sum(a, axis, dtype, out, keepdims, initial, where)
#      45 def _sum(a, axis=None, dtype=None, out=None, keepdims=False,
#      46          initial=_NoValue, where=True):
# ---> 47     return umr_sum(a, axis, dtype, out, keepdims, initial, where)
#      48
#      49 def _prod(a, axis=None, dtype=None, out=None, keepdims=False,
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
# Out:
# Index(['Unnamed: 0', 'GDP/Capita', 'MeanSchooling', 'InfantMortality',
#        'Life_exp', 'Country', 'Year', 'Country Type'],
#       dtype='object')
